# %%
import sys
print("Python:", sys.executable)
print("Starting...")
from sentence_transformers import SentenceTransformer
import pandas as pd
import numpy as np
import os
import time

NEW      = r'C:\Users\USER\Desktop\Projects\philosophy_vs_popculture_clean'
MODEL    = r'C:\Users\USER\Desktop\Projects\philosophy_and_popculture\notebooks\models\all-MiniLM-L6-v2'
OUT      = f'{NEW}/outputs'
os.makedirs(OUT, exist_ok=True)

# ── Load data ──────────────────────────────────────────────────────────
df = pd.read_csv(f'{NEW}/data/final/philosophy_vs_popculture_final.csv')
print(f"Loaded: {df.shape}")
print(df['source_type'].value_counts())

# ── Load model ─────────────────────────────────────────────────────────
print(f"\nLoading model from {MODEL}...")
model = SentenceTransformer(MODEL)
print("✅ Model loaded")

# ── Embed ──────────────────────────────────────────────────────────────
philo_texts = df[df['source_type'] == 'philosophy']['comment'].tolist()
pop_texts   = df[df['source_type'] == 'pop_culture']['comment'].tolist()

print(f"\nEmbedding {len(philo_texts):,} philosophy chunks...")
t0 = time.time()
philo_emb = model.encode(philo_texts, batch_size=64, show_progress_bar=True)
print(f"Done in {(time.time()-t0)/60:.1f} min — shape: {philo_emb.shape}")

print(f"\nEmbedding {len(pop_texts):,} pop culture comments...")
t0 = time.time()
pop_emb = model.encode(pop_texts, batch_size=64, show_progress_bar=True)
print(f"Done in {(time.time()-t0)/60:.1f} min — shape: {pop_emb.shape}")

# ── Save ───────────────────────────────────────────────────────────────
np.save(f'{OUT}/philo_embeddings.npy', philo_emb)
np.save(f'{OUT}/pop_embeddings.npy',   pop_emb)

print(f"\n✅ Saved:")
print(f"  philo_embeddings.npy — {philo_emb.shape}")
print(f"  pop_embeddings.npy   — {pop_emb.shape}")
# Out:
# Python: C:\Users\USER\venv\Scripts\python.exe
# Starting...
# Traceback (most recent call last):
#
#   File ~\venv\Lib\site-packages\IPython\core\interactiveshell.py:3699 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[3], line 4
#     from sentence_transformers import SentenceTransformer
#
#   File ~\venv\Lib\site-packages\sentence_transformers\__init__.py:15
#     from sentence_transformers.base.sampler import DefaultBatchSampler, MultiDatasetDefaultBatchSampler
#
#   File ~\venv\Lib\site-packages\sentence_transformers\base\__init__.py:4
#     from .model import BaseModel
#
#   File ~\venv\Lib\site-packages\sentence_transformers\base\model.py:24
#     from transformers import PreTrainedModel, is_datasets_available, is_torch_npu_available
#
#   File <frozen importlib._bootstrap>:1412 in _handle_fromlist
#
#   File ~\venv\Lib\site-packages\transformers\utils\import_utils.py:2207 in __getattr__
#     module = self._get_module(self._class_to_module[name])
#
#   File ~\venv\Lib\site-packages\transformers\utils\import_utils.py:2441 in _get_module
#     raise e
#
#   File ~\venv\Lib\site-packages\transformers\utils\import_utils.py:2439 in _get_module
#     return importlib.import_module("." + module_name, self.__name__)
#
#   File ~\AppData\Local\Programs\Python\Python313\Lib\importlib\__init__.py:88 in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#
#   File ~\venv\Lib\site-packages\transformers\modeling_utils.py:69
#     from .integrations.flash_paged import paged_attention_forward
#
#   File ~\venv\Lib\site-packages\transformers\integrations\flash_paged.py:7
#     @torch.compiler.disable
#
#   File ~\venv\Lib\site-packages\torch\compiler\__init__.py:259 in disable
#     import torch._dynamo
#
#   File ~\venv\Lib\site-packages\torch\_dynamo\__init__.py:13
#     from . import (
#
#   File ~\venv\Lib\site-packages\torch\_dynamo\aot_compile.py:15
#     from torch._dynamo.convert_frame import GraphRuntimeEnv
#
#   File ~\venv\Lib\site-packages\torch\_dynamo\convert_frame.py:62
#     from torch._dynamo.symbolic_convert import TensorifyState
#
#   File ~\venv\Lib\site-packages\torch\_dynamo\symbolic_convert.py:54
#     from torch._dynamo.exc import ObservedException, TensorifyScalarRestartAnalysis
#
#   File ~\venv\Lib\site-packages\torch\_dynamo\exc.py:44
#     from .utils import counters
#
#   File ~\venv\Lib\site-packages\torch\_dynamo\utils.py:70
#     import torch.fx.experimental.symbolic_shapes
#
#   File ~\venv\Lib\site-packages\torch\fx\experimental\symbolic_shapes.py:3
#     import sympy
#
#   File ~\venv\Lib\site-packages\sympy\__init__.py:31
#     from sympy.core.cache import lazy_function
#
#   File ~\venv\Lib\site-packages\sympy\core\__init__.py:4
#     from .sympify import sympify, SympifyError
#
#   File ~\venv\Lib\site-packages\sympy\core\sympify.py:11
#     from sympy.core.random import choice
#
#   File ~\venv\Lib\site-packages\sympy\core\random.py:25
#     from sympy.utilities.iterables import is_sequence
#
#   File ~\venv\Lib\site-packages\sympy\utilities\__init__.py:4
#     from .iterables import (flatten, group, take, subsets,
#
#   File ~\venv\Lib\site-packages\sympy\utilities\iterables.py:17
#     from sympy.utilities.decorator import deprecated
#
#   File ~\venv\Lib\site-packages\sympy\utilities\decorator.py:9
#     from sympy.utilities.exceptions import sympy_deprecation_warning
#
#   File <string>
# SyntaxError: source code string cannot contain null bytes
